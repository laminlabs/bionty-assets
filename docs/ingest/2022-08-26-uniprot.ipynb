# %% [markdown]
# # UniProtKB table -> `bionty.protein().df`
#
# These are the original tables that give rise to `bionty.Protein().df`
#
#
# Downloaded from: https://www.uniprot.org/uniprotkb

# %%
import pandas as pd
from lnschema_bionty import id
from nbproject import header

header()
# Out:
# <table><tbody><tr><td style='text-align: left;'><b>id</b></td><td style='text-align: left;'>Zy5A<span style='opacity:0.3'>j9yEf07A</span></td></tr><tr><td style='text-align: left;'><b>version</b></td><td style='text-align: left;'>draft</td></tr><tr><td style='text-align: left;'><b>time_init</b></td><td style='text-align: left;'>2022-09-26 15:43</td></tr><tr><td style='text-align: left;'><b>time_run</b></td><td style='text-align: left;'>2022-09-26 15:47</td></tr><tr><td style='text-align: left;'><b>pypackage</b></td><td style='text-align: left;'>lnschema_bionty==0.4.0 nbproject==0.5.3 pandas==1.4.3</td></tr></tbody></table>

# %%
filepaths = {
    "human": "~/Downloads/uniprot-human.tsv.gz",
    "mouse": "~/Downloads/uniprot-mouse.tsv.gz",
}

# %%
for species, filepath in filepaths.items():
    print(f"Loading {species} data...")

    df = pd.read_csv(filepath, sep="\t")

    # add ids to each entry
    ids = []
    for i in df.index:
        ids.append(id.protein())
    df.index = ids
    df.index.name = "id"

    print(f"shape: {df.shape}")
    display(df.head())

    filename = f"uniprot-{species}.parquet"
    df.to_parquet(filename)

    print(f"Wrote {filename}.")
    print("------------------------------------------------")
# Out:
# Loading human data...
# shape: (204961, 9)
#             Entry        Entry Name  \
# id
# vFZns  A0A024QZ08  A0A024QZ08_HUMAN
# KJePI  A0A024QZ86  A0A024QZ86_HUMAN
# xDzVh  A0A024QZA8  A0A024QZA8_HUMAN
# zxyMy  A0A024QZB8  A0A024QZB8_HUMAN
# ncF5u  A0A024QZQ1  A0A024QZQ1_HUMAN
#
#                                            Protein names  Length  \
# id
# vFZns  Intraflagellar transport 20 homolog (Chlamydom...     132
# KJePI                             T-box 2, isoform CRA_a     712
# xDzVh      Receptor protein-tyrosine kinase, EC 2.7.10.1     976
# zxyMy                                           Battenin     438
# ncF5u  Sirtuin (Silent mating type information regula...     747
#
#        Organism (ID) Gene Names (primary) Gene Names (synonym) Ensembl  GeneID
# id
# vFZns           9606                IFT20                  NaN     NaN  90410;
# KJePI           9606                 TBX2                  NaN     NaN   6909;
# xDzVh           9606                EPHA2                  NaN     NaN   1969;
# zxyMy           9606                 CLN3                  NaN     NaN   1201;
# ncF5u           9606                SIRT1                  NaN     NaN  23411;
# Wrote uniprot-human.parquet.
# ------------------------------------------------
# Loading mouse data...
# shape: (86436, 9)
#             Entry        Entry Name  \
# id
# csujM  A0A075F5C6  A0A075F5C6_MOUSE
# rIW0Q  A0A087WPF7       AUTS2_MOUSE
# MPFTz  A0A087WPT2  A0A087WPT2_MOUSE
# BAyI0  A0A087WPU4  A0A087WPU4_MOUSE
# O2WoB  A0A087WRK1  A0A087WRK1_MOUSE
#
#                                            Protein names  Length  \
# id
# csujM  Heat shock factor protein 1 (Heat shock transc...     531
# rIW0Q       Autism susceptibility gene 2 protein homolog    1261
# MPFTz                       Prostaglandin G/H synthase 2      62
# BAyI0                            FAT atypical cadherin 1     159
# O2WoB  Predicted gene, 20814 (Predicted gene, 20850) ...     222
#
#        Organism (ID) Gene Names (primary)  \
# id
# csujM          10090                 Hsf1
# rIW0Q          10090                Auts2
# MPFTz          10090                Ptgs2
# BAyI0          10090                 Fat1
# O2WoB          10090              Gm20850
#
#                                     Gene Names (synonym)  \
# id
# csujM                                                NaN
# rIW0Q                                           Kiaa0442
# MPFTz                                                NaN
# BAyI0                                                NaN
# O2WoB  Gm20814 Gm20835 Gm20855 Gm20869 Gm20870 Gm2088...
#
#                                                  Ensembl  \
# id
# csujM                              ENSMUST00000228371.2;
# rIW0Q  ENSMUST00000161226 [A0A087WPF7-1];ENSMUST00000...
# MPFTz                              ENSMUST00000190784.2;
# BAyI0                              ENSMUST00000186342.3;
# O2WoB  ENSMUST00000185240.2;ENSMUST00000185245.2;ENSM...
#
#                                                   GeneID
# id
# csujM                                             15499;
# rIW0Q                                                NaN
# MPFTz                                                NaN
# BAyI0                                                NaN
# O2WoB  100042201;100042279;100042594;100861691;108167...
# Wrote uniprot-mouse.parquet.
# ------------------------------------------------
